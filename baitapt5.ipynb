# %% [markdown]
# Viết hàm truyền vào hai số nguyên a, b. Trả về số lớn hơn trong hai số. def Max_Of_Two( a, b) ->
# int:

# %%
def max_of_tow(a,b):
    if a>b: return a
    else: return b

    
a,b=map(int, input().split())
print(max_of_tow(a, b))
# Out:
# 6

# %% [markdown]
# Viết hàm hoán đổi hai số nguyên. def swap(a, b) -> Tuple[int, int]:

# %%
def swap(a,b):
    return(b, a)
a,b=map(int, input().split())
print(swap(a,b))
# Out:
# (9, 6)

# %% [markdown]
# Viết hàm kiểm tra một số có phải là số nguyên tố hay không?

# %%
def kt_snt(n):
    if n<2:
        return False
    for i in range(2, int(n**0.5)+1):
        if n%i==0:
            return False
    return True
        
print(kt_snt(int(input())))
# Out:
# False

# %%
import math
def is_prime(n: int) -> bool:
    if n < 2: return False
    for i in range(2, int(math.sqrt(n)) + 1):
        if n % i == 0: return False
    return True

# %% [markdown]
# VIết hàm kiểm tra một số có phải số hoàn hảo hay không, xử lý trên dữ liệu kiểu số nguyên

# %%
n=int(input())
def shh(n):
    tong=0
    for i in range(1,n):
        if n%i==0:
            tong+=i
    if tong==n:
        return True
    return False
print(shh(n))
# Out:
# False

# %%
def is_perfect_number(n: int) -> bool:
    if n < 1: return False
    return sum(i for i in range(1, n) if n % i == 0) == n

# %% [markdown]
# Viết hàm đưa vào một list số nguyên và một số nguyên dương k. Hãy tìm và trả về vị trí của phần tử
# đầu tiên có giá trị k trong list số nguyên, nếu không có thì trả về -1

# %%
danhsach=list(map(int, input().split()))
n=int(input())
count=0
for i in danhsach:
    count+=1
    if i==n:
        break
print(danhsach)
print(f"vi tri so {count}")
# Out:
# [6, 5, 4, 58, 5, 45, 54, 4, 4, 4, 4, 4, 54, 2, 34, 534, 6, 5645, 65, 6, 46, 78, 8, 565, 89, 9, 6, 5]
# vi tri so 3

# %%
def find_first_k(lst: list, k: int) -> int:
    for index, value in enumerate(lst):
        if value == k: return index
    return -1

# %%
danhsach=list(map(int, input().split()))
n=int(input())
def vi_tri(n,danhsach):
    count=0
    for i in danhsach:
        count+=1
        if i==n:
            break
    return count
print(danhsach)
print(vi_tri(n,danhsach))
# Out:
# [45, 5, 4, 4, 45, 6, 43, 345, 5, 43, 34, 5, 4343, 5, 45, 43]
# 2

# %% [markdown]
# Viết hàm tính giai thừa. Nhập vào số nguyên n, trả về giai thừa của n (n!)

# %%
def tinh_giai_thua(a):
    tinh=1
    if a>0:
        for i in range(1, a+1):
            tinh*=i
        return tinh
    if a==0:
        return tinh
print(tinh_giai_thua(int(input())))
# Out:
# 1

# %% [markdown]
# Viết hàm giả lập một máy tính bỏ túi.
# Hàm thực hiện tính toán kết quả của phép toán giữa số \( num1 \) và \( num2 \) với toán tử \( operat
# \)
# Biết các toán tử đơn giản thực hiện phép toán lần lượt là:
# Phép trừ \( - \)
# Phép cộng \( + \)
# Phép chia \( / \)
# Phép nhân \( * \)
# Kết quả làm tròn đến chữ số thập phân thứ hai.
# Đầu vào: Hai số thực và phép toán cần thực hiện (trong số các phép toán \(+, -, *, /\)).
# Đầu ra: Kết quả phép toán.

# %%
def compute(num1: float, num2: float, op: str) -> float:
    if op == '+': result = num1 + num2
    elif op == '-': result = num1 - num2
    elif op == '*': result = num1 * num2
    elif op == '/': 
        result = num1 / num2 if num2 != 0 else 0
    else: return 0
    return round(result, 2)
a, op, b = input("Nhập số a, số b và phép toán: ").split()
a, b = float(a), float(b)
print(compute(a, b, op))
# Out:
# -1.0

# %% [markdown]
# Khoảng cách Hamming giữa hai số nguyên là số lượng vị trí khác nhau giữa hai dãy bits tương ứng
# của chúng. Ví dụ: Khoảng cách Hamming giữa 1 (1) và 4 (100) là 2.
# Cho hai số nguyên x và y, hãy viết hàm trả về khoảng cách Hamming giữa hai số này.
# Khoảng cách Hamming là cái tên được đặt theo tên của Richard Hamming, người giới thiệu lý
# thuyết này trong tài liệu có tính cơ sở của ông về mã phát hiện lỗi và sửa lỗi (error-detecting and
# error-correcting codes). Nó được sử dụng trong kỹ thuật viễn thông để tính số lượng các bit trong
# một từ nhị phân (binary word) bị đổi ngược, như một hình thức để ước tính số lỗi xảy ra trong quá
# trình truyền thông, và vì thế, đôi khi, nó còn được gọi là khoảng cách tín hiệu (signal distance). Việc
# phân tích trọng số Hamming của các bit còn được sử dụng trong một số ngành, bao gồm lý thuyết
# tin học, lý thuyết mã hóa, và mật mã học. Tuy vậy, khi so sánh các dãy ký tự có chiều dài khác
# nhau, hay các dãy ký tự có xu hướng không chỉ bị thay thế không thôi, mà còn bị ảnh hưởng bởi dữ
# liệu bị lồng thêm vào, hoặc bị xóa đi, phương pháp đo lường phức tạp hơn, như khoảng cách
# Levenshtein (Levenshtein distance) là một phương pháp có tác dụng và thích hợp hơn.

# %%
def hamming_distance(x: int, y: int) -> int:
    # XOR tìm các bit khác nhau, sau đó đếm số lượng bit 1
    return bin(x ^ y).count('1')

# %% [markdown]
# Viết hàm trả về tổng các chữ số của số nguyên dương n

# %%
def sum_of_digits(n: int) -> int:
    return sum(int(d) for d in str(abs(n)))

# %% [markdown]
# Hai từ được gọi là đẳng cấu nếu các kí tự trong một từ có thể được ánh xạ để được từ còn lại. Ánh
# xạ một kí tự nghĩa là thay đổi toàn bộ các kí tự đó trong từ bởi một kí tự khác. Thứ tự của các kí tự
# được giữ không đổi. Hai kí tự khác nhau không thể ánh xạ đến cùng một kí tự, nhưng một kí tự có
# thể ánh xạ thành chính nó. Ví dụ, từ "abca" và "zbxz" là hai từ đẳng cấu vì ta có thể ánh xạ 'a' thành
# 'z', 'b' thành 'b' và 'c' thành 'x'.
# Viết hàm trả về \(true\) nếu hai từ \(a\) và \(b\) là đẳng cấu, ngược lại \(false\). Bạn có thể giả sử hai từ đầu vào có cùng độ dài.

# %%
def is_isomorphic(a: str, b: str) -> bool:
    if len(a) != len(b): return False
    d1, d2 = {}, {}
    for char_a, char_b in zip(a, b):
        if char_a not in d1: d1[char_a] = char_b
        if char_b not in d2: d2[char_b] = char_a
        if d1[char_a] != char_b or d2[char_b] != char_a:
            return False
    return True

# %%
def kiem_tra_dang_cau(chuoi_1, chuoi_2):
    
    if len(chuoi_1) != len(chuoi_2):
        return False
    
   
    so_ben_trai = {} # Luu: chu_cai_1 -> chu_cai_2
    so_ben_phai = {} # Luu: chu_cai_2 -> chu_cai_1
    
    # Duyet tung cap chu cai o cung vi tri 
    for chu_1, chu_2 in zip(chuoi_1, chuoi_2):
        
        # 1. Kiem tra xem chu_1 da "dang ky" di voi ai chua
        if chu_1 in so_ben_trai:
            if so_ben_trai[chu_1] != chu_2:
                return False 
        else:
            so_ben_trai[chu_1] = chu_2
            
        # 2. Kiem tra nguoc lai xem chu_2 da bi ai "hot" mat chua
        if chu_2 in so_ben_phai:
            if so_ben_phai[chu_2] != chu_1:
                return False # Chu_2 da co chu roi, chu_1 khong duoc xen vao!
        else:
            so_ben_phai[chu_2] = chu_1
            
    return True

# %% [markdown]
# W5A11 Viết hàm is_product_divisible_by_10(a, b) trả về True nếu tích a*b chia hết cho 10, ngược lại False

# %%
def is_product_divisible_by_10(a: int, b: int) -> bool:
    return (a * b) % 10 == 0

# %% [markdown]
# W5A12
# Viết hàm divide_with_remainder(dividend, divisor) trả về bộ (q, r) sao cho dividend = divisor*q + r và
# 0 <= |r| < |divisor|.

# %%
def divide_with_remainder(dividend: int, divisor: int) -> tuple:
    q = dividend // divisor
    r = dividend % divisor
    return (q, r)

# %% [markdown]
# W5A13 Viết hàm max_of_two(a, b) trả về số lớn hơn trong hai số.

# %%
def max_of_two_v2(a: int, b: int) -> int:
    return max(a, b)

# %% [markdown]
# W5A14 Viết hàm compute(a, b, op) thực hiện phép tính a (+|-|*|/) b tùy theo ký tự op.

# %%
def compute(a: float, b: float, op: str) -> float:
    ops = {'+': a + b, '-': a - b, '*': a * b, '/': a / b if b != 0 else None}
    return ops.get(op, "Invalid")

# %% [markdown]
# W5A15 Viết hàm is_right_triangle(a, b, c) trả về True nếu ba số có thể là ba cạnh của tam giác vuông

# %%
def is_right_triangle(a: float, b: float, c: float) -> bool:
    if a <= 0 or b <= 0 or c <= 0: return False
    s = sorted([a, b, c])
    return round(s[0]**2 + s[1]**2, 5) == round(s[2]**2, 5)
