# %% [markdown]
# ### Bài 1: Nhập vào số nguyên n, in ra màn hình số gấp đôi của n

# %%
n = int(input("Nhập vào số nguyên n: "))
ket_qua = n * 2
print("Số gấp đôi của n là:", ket_qua)
# Out:
# Số gấp đôi của n là: 6

# %% [markdown]
# ### Bài 2: Một khu đất hình chữ nhật có chiều rộng a, chiều dài b. Người ra xây một khu vui chơi hình tròn tại vị trí trung tâm khu đất như hình vẽ. Nhập vào a, b. Hãy tính phần diện tích còn để trồng cây xung quanh là bao nhiêu. Biết pi = 3.14, lấy kết quả đến 2 chữ số phần thập phân.

# %%
a = float(input("Nhập chiều rộng a: "))
b = float(input("Nhập chiều dài b: "))
s_hcn = a * b
r = a / 2
s_tron = 3.14 * (r ** 2)
s_con_lai = s_hcn - s_tron
print(f"Diện tích còn lại để trồng cây là: {s_con_lai:.2f}")
# Out:
# Diện tích còn lại để trồng cây là: 33705.38

# %% [markdown]
# ### Bài 3: Viết chương trình nhập vào một “kí tự” c, nếu nó là chữ hoa thì in ra chữ thường tương ứng và ngược lại nếu nó là chữ thường thì in ra chữ hoa tương ứng của nó. (xem trước cấu trúc lựa chọn: if….else, ma)

# %%
c = input("Nhập vào một kí tự: ")
if c.isupper():
    print(c.lower())
else:
    print(c.upper())
# Out:
# T

# %% [markdown]
# ### Bài 4: Viết chương trình nhập vào một “kí tự”, Kiểm tra xem c có phải là kí tự chữ cái không (hoa hoặc thường). Nếu đúng thì in ra “{c} là kí tự alphabet”, nếu sai in ra “{c} không phải là kí tự alphabet.

# %%
c = input("nhập kí tự:")
if len(c)==1:
  if c.isalpha():
    print(f"{c} là kí tự alphabet")
  else:
    print(f"{c} không phải là kí tự alphabet")
else:
  print("nhập lại kí tự")
# Out:
# F là kí tự alphabet

# %% [markdown]
# ### Bài 5: Nhập vào chữ cái hoa A, in ra chữ cái thường liền trước chữ cái a thường tương ứng của A. Xét TH khi c = ‘A’ là đặc biệt.

# %%
A = input("nhập vào 1 chữ cái in hoa:")
if len(A)==1:

 if A.isupper():
  if A == 'A':
    print('z')
  else:
    c_thuong = A.lower()
    ket_qua = chr(ord(c_thuong) - 1)
    print(ket_qua)
 else:
   print('nhập lỗi ')
else:
  print("nhập lỗi")
# Out:
# nhập lỗi

# %% [markdown]
# ### Bài 6. Nhập vào 3 số a, b, c. Kiểm tra xem đây có phải là cạnh của 1 tam giác không, nếu đúng thì tính diện tích của tam giác đó, in ra với 1 chữ số phần thập phân, nếu nó không phải 3 cạnh của tam giác thì in ra “Khong phai 3 canh cua tam giac”.

# %%
import math

try:

    a, b, c = map(float, input("Nhập ba số a, b, c lần lượt là: ").split())


    if a>0 and b>0 and c>0 and a + b > c and a + c > b and b + c > a:
        p = (a + b + c) / 2         
        s = math.sqrt(p * (p - a) * (p - b) * (p - c))
        print(f"Kết quả diện tích: {s:.1f}")
        if a==b==c:
            print('là tam giác đều')
        elif a== (b**2+c**2)**0.5 or b== (a**2+c**2)**0.5 or c== (b**2+a**2)**0.5 :
            print('tam giác vuông')
        elif a==b or a==c or b==c:
            if a== (b**2+c**2)**0.5 or b== (a**2+c**2)**0.5 or c== (b**2+a**2)**0.5 :
                print('là tam giác vuông cân')
            else:
                print('là tam giác cân')
        else: 
            print('tam giác thường')    
    else:
        print("Không phải 3 cạnh của tam giác")

except ValueError:

    print("Lỗi")
# Out:
# Không phải 3 cạnh của tam giác

# %% [markdown]
# ### Bài 7: Nhập vào một chuỗi gồm các kí tự thường độ dài >=20, in ra chữ cái thứ năm và thứ chín của chuỗi này.

# %%
while True:
    s = input("Nhập chuỗi (độ dài >= 20): ")
    
    if len(s) >= 20:
        print("kí tự thứ 5 là:",s[4],", kí tự thứ 9 là:", s[8])
        break
    else:
        print("Lỗi: Chuỗi quá ngắn, vui lòng nhập lại!")
# Out:
# Lỗi: Chuỗi quá ngắn, vui lòng nhập lại!
# kí tự thứ 5 là: d , kí tự thứ 9 là: s

# %% [markdown]
# Bài 8: Nhập vào họ tên chủ hộ và chỉ số điện kế tháng trước và chỉ số điện kế tháng này,
# tính tiền điện tháng này cho hộ biết:
# - Từ 0 – 50kWh: 1.984 đồng/kWh
# - Bậc 2: Từ 51 – 100 kWh: 2.050 đồng/kWh
# - Bậc 3: Từ 101 – 200 kWh: 2.380 đồng/kWh
# - Bậc 4: Từ 201 – 300 kWh: 2.998 đồng/kWh
# - Bậc 5: Từ 301 – 400 kWh: 3.350 đồng/kWh
# - Bậc 6: Từ 401 trở đi kWh: 3.460 đồng/kWh
# Tính thêm tiền VAT 8%. Chỉ lấy đến đơn vị đồng

# %%
ten = input("Ten chu ho: ")
cu = int(input("Chi so thang truoc: "))
moi = int(input("Chi so thang nay: "))
kwh = moi - cu
tien = 0

if kwh <= 50:
    tien = kwh * 1984
elif kwh <= 100:
    tien = 50 * 1984 + (kwh - 50) * 2050
elif kwh <= 200:
    tien = 50 * 1984 + 50 * 2050 + (kwh - 100) * 2380
elif kwh <= 300:
    tien = 50 * 1984 + 50 * 2050 + 100 * 2380 + (kwh - 200) * 2998
elif kwh <= 400:
    tien = 50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + (kwh - 300) * 3350
else:
    tien = 50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + 100 * 3350 + (kwh - 400) * 3460

tong_tien = tien * 1.08
print(f"Ho va ten: {ten}")
print(f"Tien phai tra la: {round(tong_tien)}")
# Out:
# Ho va ten: Nguyênklsdahfh
# Tien phai tra la: 111922949

# %% [markdown]
# ##### Một số bài tập khác

# %% [markdown]
# 1. Kiểm tra số chẵn lẻ: Viết chương trình nhập một số nguyên, kiểm tra và in ra số đó
# là số chẵn hay số lẻ

# %%
n = int(input())
if n % 2 == 0:
    print(f"{n} là Số chẵn")
else:
    print(f"{n} là Số lẻ")
# Out:
# 7 là Số lẻ

# %% [markdown]
# 2. Kiểm tra số có tận cùng 5 không: Viết chương trình nhập một số nguyên, kiểm tra
# số đó có tận cùng 5 không, nếu đúng in ra “True”, nếu sai in ra “False”.

# %%
n = int(input())
if abs(n) % 10 == 5:
    print("True")
else:
    print("False")
# Out:
# False

# %% [markdown]
# 3. Kiểm tra số có chia hết cho 3 và 5 không: Viết chương trình nhập một số nguyên,
# kiểm tra số đó có chia hết cho 3 và 5 không, nếu đúng in ra “True”, nếu sai in ra
# “False”.

# %%
n = int(input())
if n % 3 == 0 and n % 5 == 0:
    print("True")
else:
    print("False")
# Out:
# False

# %% [markdown]
# 4. Kiểm tra tuổi đủ điều kiện bầu cử: Viết chương trình nhập năm sinh của một
# người, kiểm tra xem người đó có đủ 18 tuổi để đi bầu cử hay không.

# %%
nam_sinh = int(input("nhập năm sinh:"))
namht=int(input("nhập năm hiện tại:"))
tuoi = namht - nam_sinh
if tuoi >= 18:
    print("Đủ điều kiện bầu cử")
else:
    print("Chưa đủ điều kiện bầu cử")
# Out:
# Chưa đủ điều kiện bầu cử

# %% [markdown]
# 5. So sánh 2 số: Viết chương trình nhập vào hai số, in ra số lớn hơn hoặc thông báo
# nếu hai số bằng nhau.

# %%
a = float(input())
b = float(input())
if a > b:
    print(f"{a} là số lớn hơn")

    
elif b > a:
    print(f"{b} là số lớn hơn")
else:
    print("Hai số bằng nhau")
# Out:
# 5.0 là số lớn hơn

# %% [markdown]
# 6. Kiểm tra ký tự nhập vào là chữ hay số: Viết chương trình nhập một ký tự, kiểm
# tra xem ký tự đó là chữ cái hay số.

# %%
c = input("nhập kí tự:")
if c.isalpha():
    print(f"{c} là chữ cái")
elif c.isdigit():
    print(f"{c} là chữ số")
else:
    print(f"{a} là ký tự đặc biệt")
# Out:
# 351 là chữ số

# %% [markdown]
# 7. Bài tập 5: Tính điểm học lực Nhập điểm (0-10), phân loại học lực theo quy tắc: >=8: Giỏi; >=6.5 và <8: Khá; >=5 và <6.5: Trung bình; <5: Yếu

# %%
diem = float(input())
if diem >= 8:
    print(f"{diem} là học lực giỏi")
elif diem >= 6.5:
    print(f"{diem} là học lực khá")
elif diem >= 5:
    print(f"{diem} là học lực trung bình")
else:
    print(f"{diem} là học lực yếu")
# Out:
# 5.0 là học lực trung bình

# %% [markdown]
# 8. Kiểm tra năm nhuận: Viết chương trình nhập năm, kiểm tra xem năm đó có phải
# năm nhuận hay không. (Năm nhuận nếu chia hết cho 400 hoặc chia hết cho 4
# nhưng không chia hết cho 100)

# %%
nam = int(input())
if (nam % 400 == 0) or (nam % 4 == 0 and nam % 100 != 0):
    print(f"{nam} là năm nhuận")
else:
    print(f"{nam} không là năm nhuận")
# Out:
# 2026 không là năm nhuận

# %% [markdown]
# 9. Chuyển đổi số thành chữ số: Nhập một số nguyên từ 0 đến 9, in ra tên chữ số tương ứng (0 -> "Không", 1 -> "Một", ...) – Xem trước match …case

# %%
n = int(input())
match n:
    case 0: print("Không")
    case 1: print("Một")
    case 2: print("Hai")
    case 3: print("Ba")
    case 4: print("Bốn")
    case 5: print("Năm")
    case 6: print("Sáu")
    case 7: print("Bảy")
    case 8: print("Tám")
    case 9: print("Chín")
    case _: print("Số nhập vào không nằm trong khoảng 0-9")
# Out:
# Năm

# %% [markdown]
# 10.Kiểm tra điểm thi xem có qua môn hay phải học lại: Nhập điểm thi, nếu điểm >=
# 4 thì in "Qua môn", ngược lại in "Học lại".

# %%
diem = float(input())
if diem >= 4:
    print("Qua môn")
else:
    print("Học lại")
# Out:
# Qua môn

# %% [markdown]
# 11.Kiểm tra năm sinh và tính tuổi: Nhập năm sinh, tính tuổi hiện tại (giả sử năm
# hiện tại là 2025), và kiểm tra xem người đó có đủ 18 tuổi hay chưa.

# %%
nam_sinh = int(input())
tuoi = 2025 - nam_sinh
print(f"Tuổi: {tuoi}")
if tuoi >= 18:
    print("Đã đủ 18 tuổi")
else:
    print("Chưa đủ 18 tuổi")
# Out:
# Tuổi: 26
# Đã đủ 18 tuổi
